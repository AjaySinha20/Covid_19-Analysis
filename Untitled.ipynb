# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime
import plotly.graph_objects as go

# %%
covid_df=pd.read_csv('worldometer_data.csv')

# %%
covid_df.head(10)
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
# 5         Mexico  North America  1.290662e+08      462690    6590.0
# 6           Peru  South America  3.301632e+07      455409       NaN
# 7          Chile  South America  1.913251e+07      366671       NaN
# 8       Colombia  South America  5.093626e+07      357710       NaN
# 9          Spain         Europe  4.675665e+07      354530       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
covid_df.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02     4.000000     188.000000    3.000000
# mean   3.041549e+07  9.171850e+04  1980.500000    3792.590426  300.000000
# std    1.047661e+08  4.325867e+05  3129.611424   15487.184877  451.199512
# min    8.010000e+02  1.000000e+01    20.000000       1.000000    1.000000
# 25%    9.663140e+05  7.120000e+02    27.500000      22.000000   40.500000
# 50%    7.041972e+06  4.491000e+03   656.000000     113.000000   80.000000
# 75%    2.575614e+07  3.689600e+04  2609.000000     786.000000  449.500000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02      3.000000  2.050000e+02        122.000000
# mean     5.887898e+04   1706.000000  2.766433e+04        534.393443
# std      2.566984e+05   2154.779803  1.746327e+05       2047.518613
# ...

# %%
date_df=pd.read_csv('day_wise.csv')

# %%
date_df.head(10)
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
# 5  2020-01-27       2927      82         61    2784        809          26
# 6  2020-01-28       5578     131        107    5340       2651          49
# 7  2020-01-29       6166     133        125    5908        588           2
# 8  2020-01-30       8234     171        141    7922       2068          38
# 9  2020-01-31       9927     213        219    9495       1693          42
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# ...

# %%
date_df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
sns.relplot(x='TotalCases',y='TotalRecovered',data=covid_df, kind='line')

# %%
sns.pairplot(covid_df)

# %%
populationscale=np.array(covid_df['Population'].dropna())
#print(populationscale)
mean=np.mean(populationscale)
#print(mean)
std_dev=np.std(populationscale)
#print(std_dev)
target_mean=0
target_std_dev=1
scaled_population=(populationscale-mean)/((std_dev*target_std_dev)+target_mean)
print(scaled_population)
# Out:
# [ 2.87791850e+00  1.74421881e+00  1.29258291e+01  1.10535897e+00
#   2.77150350e-01  9.43899535e-01  2.48850217e-02 -1.07956617e-01
#   1.96344834e-01  1.56353868e-01  5.13636062e-01  3.58866356e-01
#   4.25821801e-02  1.82636247e+00  1.28629631e+00  2.87397804e-01
#   5.16800310e-01  1.41812613e-01  5.10896112e-01  3.33666630e-01
#   9.46336600e-02  7.58819551e-01  2.32880747e+00  7.04167694e-02
#  -2.64153070e-01 -1.11150899e-01  6.89869964e-01 -1.21961350e-01
#  -1.79182082e-01 -1.94327074e-01 -2.42044626e-01 -2.03014967e-01
#   1.27163603e-01 -1.87121797e-01 -2.49671971e-01 -1.80078804e-01
#  -2.50098938e-01 -2.00609441e-01 -1.96274345e-01 -1.07081050e-01
#  -1.27033094e-01 -2.34997854e-01 -1.19300700e-01 -1.93485110e-01
#   7.10605112e-02  1.68581137e+00 -1.96105707e-01 -2.74688850e-01
#   9.18732551e-01 -2.62660389e-01  6.86985802e-03 -2.28495880e-01
#   8.22278716e-02 -2.08149573e-01  1.29270700e-01 -1.93919023e-01
# ...

# %%
px.bar(covid_df,x=covid_df['Country/Region'],y=covid_df['TotalCases'],color=covid_df['Population'])

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
fig5=go.Figure()
fig5.add_trace(go.Scatter(x=covid_df['TotalCases'],y=covid_df['TotalRecovered'],mode='lines+markers',
                    name='lines+markers'))

# %%
fig4=go.Figure()
fig4.add_trace(go.Scatter(x=covid_df['TotalCases'],y=covid_df['TotalDeaths'],mode='lines+markers',
                    name='lines+markers'))

# %%
px.pie(values=covid_df['TotalTests'].values,names=covid_df['Continent'])

# %%
px.bar(covid_df,x=covid_df['Country/Region'],y=covid_df['TotalTests'],color=covid_df['ActiveCases'])

# %%
date_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB

# %%
px.bar(date_df,x=date_df['Date'],y=date_df['Active'],color=date_df['Deaths'])

# %%
px.scatter(date_df,x=date_df['Date'], y=date_df['New cases'],size=date_df['New cases'],title='New Cases vs Date')

# %%
date_df
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
date_df.head(20)
# Out:
#           Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0   2020-01-22        555      17         28     510          0           0
# 1   2020-01-23        654      18         30     606         99           1
# 2   2020-01-24        941      26         36     879        287           8
# 3   2020-01-25       1434      42         39    1353        493          16
# 4   2020-01-26       2118      56         52    2010        684          14
# 5   2020-01-27       2927      82         61    2784        809          26
# 6   2020-01-28       5578     131        107    5340       2651          49
# 7   2020-01-29       6166     133        125    5908        588           2
# 8   2020-01-30       8234     171        141    7922       2068          38
# 9   2020-01-31       9927     213        219    9495       1693          42
# 10  2020-02-01      12038     259        281   11498       2111          46
# ...

# %%
figx=go.Figure()
figx.add_trace(go.Scatter(x=date_df['Date'],y=date_df['New recovered'],mode='lines+markers',name='New recovered'))
figx.add_trace(go.Scatter(x=date_df['Date'],y=date_df['New cases'],mode='lines+markers',name='New cases'))
figx.update_layout(title='(New case vs New recovered) per Day',xaxis_title='Date',yaxis_title='Population')
figx.show()

# %%
def country_statis(c_name):
    return((covid_df[covid_df['Country/Region']==c_name]))

# %%
country_statis('India')
# Out:
#   Country/Region Continent    Population  TotalCases  NewCases  TotalDeaths  \
# 2          India      Asia  1.381345e+09     2025409       NaN      41638.0
#
#    NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 2        NaN       1377384.0           NaN     606387.0            8944.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region
# 2            1466.0           30.0  22149351.0       16035.0  South-EastAsia

# %%
grouped_df=pd.read_csv('full_grouped.csv')

# %%
grouped_df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active    New cases  \
# count  3.515600e+04   35156.000000  3.515600e+04  3.515600e+04  35156.00000
# mean   2.356663e+04    1234.068239  1.104813e+04  1.128443e+04    469.36375
# std    1.499818e+05    7437.238354  6.454640e+04  8.997149e+04   3005.86754
# min    0.000000e+00       0.000000  0.000000e+00 -2.000000e+00      0.00000
# 25%    1.000000e+00       0.000000  0.000000e+00  0.000000e+00      0.00000
# 50%    2.500000e+02       4.000000  3.300000e+01  8.500000e+01      2.00000
# 75%    3.640250e+03      78.250000  1.286250e+03  1.454000e+03     75.00000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  77255.00000
#
#          New deaths  New recovered
# count  35156.000000   35156.000000
# mean      18.603339     269.315593
# std      115.706351    2068.063852
# min    -1918.000000  -16298.000000
# 25%        0.000000       0.000000
# 50%        0.000000       0.000000
# ...

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            35156 non-null  object
#  1   Country/Region  35156 non-null  object
#  2   Confirmed       35156 non-null  int64
#  3   Deaths          35156 non-null  int64
#  4   Recovered       35156 non-null  int64
#  5   Active          35156 non-null  int64
#  6   New cases       35156 non-null  int64
#  7   New deaths      35156 non-null  int64
#  8   New recovered   35156 non-null  int64
#  9   WHO Region      35156 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 2.7+ MB

# %%
grouped_df.head(100000)
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
def daywisereport(gr_cnames,gr_date):
   return (grouped_df[(grouped_df['Country/Region']==gr_cnames)&(grouped_df['Date']==gr_date)])

# %%
daywisereport('India','2020-08-22')
# Out:
# Empty DataFrame
# Columns: [Date, Country/Region, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, WHO Region]
# Index: []
